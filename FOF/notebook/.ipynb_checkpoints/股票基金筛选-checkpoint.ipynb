# %%
from WindPy import w
import pandas as pd
import numpy as np
import pyfolio as pf
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import sys
# %matplotlib inline

# %%
w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
# You can use w.menu to help yourself to create commands(WSD,WSS,WST,WSI,WSQ,...)!
#
# COPYRIGHT (C) 2016 WIND HONGHUI INFORMATION & TECHKNOLEWDGE CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %%
DATA_DIR = 'D:/Data/fund'
end_date = '2017-04-13'
rptDate = '20161231'

# %%
def wind2df(raw_data):
    dic = {}
    for data, field in zip(raw_data.Data, raw_data.Fields):
        dic[str(field.lower())] = data
    return pd.DataFrame(dic)

# %%
data = w.wset("sectorconstituent","date=2017-04-12;windcode=885012.WI")

# %%
df = wind2df(data)

# %%
fname = u'%s/股票型基金列表.xlsx'%(DATA_DIR)
df[['sec_name', 'wind_code']].to_excel(fname, index=False)

# %%
df = pd.read_excel(fname)

# %%
data = w.wss(df['wind_code'].tolist(), "fund_investtype")

# %%
temp = wind2df(data)

# %%
df['investtype'] = temp['fund_investtype']

# %%
df.head()
# Out:
#        sec_name  wind_code investtype
# 0  嘉实中证500ETF联接  000008.OF    被动指数型基金
# 1     财通中证100增强  000042.OF    增强指数型基金
# 2  华夏沪深300ETF联接  000051.OF    被动指数型基金
# 3    国联安中证医药100  000059.OF    被动指数型基金
# 4       嘉实研究阿尔法  000082.OF    普通股票型基金

# %%
data = w.wss(df['wind_code'].tolist(), "issue_date")

# %%
temp = wind2df(data)

# %%
df['issue_date'] = temp['issue_date']

# %%
data = w.wss(df['wind_code'].tolist(), "prt_netasset","rptDate=%s"%(rptDate))

# %%
temp = wind2df(data)

# %%
df['netasset'] = temp['prt_netasset']

# %%
data = w.wss(df['wind_code'].tolist(), "fund_fundmanager")

# %%
temp = wind2df(data)

# %%
df['fundmanager'] = temp['fund_fundmanager']

# %%
data = w.wss(df['wind_code'].tolist(), "fund_dq_status","tradeDate=2017-04-13")

# %%
temp = wind2df(data)

# %%
df['fund_status'] = temp['fund_dq_status']

# %%
df.to_excel(fname, index=False)

# %%
df.shape
# Out:
# (696, 7)

# %%
for x in df['investtype'].unique():
    print x
# Out:
# 被动指数型基金
# 增强指数型基金
# 普通股票型基金
# 偏股混合型基金

# %%
pnl = pd.read_pickle('C:/Users/jgtzsx01/Documents/workspace/data/FOF/stock.pkl')
fname = u'%s/股票型基金列表.xlsx'%(DATA_DIR)
df = pd.read_excel(fname)

# %%
pnl.major_axis
# Out:
# DatetimeIndex(['2010-01-04 00:00:00.005000', '2010-01-05 00:00:00.005000',
#                '2010-01-06 00:00:00.005000', '2010-01-07 00:00:00.005000',
#                '2010-01-08 00:00:00.005000', '2010-01-11 00:00:00.005000',
#                '2010-01-12 00:00:00.005000', '2010-01-13 00:00:00.005000',
#                '2010-01-14 00:00:00.005000', '2010-01-15 00:00:00.005000',
#                ...
#                '2017-03-30 00:00:00.005000', '2017-03-31 00:00:00.005000',
#                '2017-04-05 00:00:00.005000', '2017-04-06 00:00:00.005000',
#                '2017-04-07 00:00:00.005000', '2017-04-10 00:00:00.005000',
#                '2017-04-11 00:00:00.005000', '2017-04-12 00:00:00.005000',
#                '2017-04-13 00:00:00.005000', '2017-04-14 00:00:00.005000'],
#               dtype='datetime64[ns]', length=1767, freq=None)

# %%
pnl.minor_axis
# Out:
# Index([u'nav_adj', u'3-year return', u'2-year return', u'1-year return',
#        u'6-month return', u'3-month return', u'1-month return'],
#       dtype='object')

# %%
df[df['sec_name'] == u'偏股混合型基金']
# Out:
# Empty DataFrame
# Columns: [sec_name, wind_code, investtype, issue_date, netasset, fundmanager, fund_status]
# Index: []

# %%
ret_df = pnl[df['wind_code']].minor_xs('1-year return')

# %%
df.loc[:, 'max return'] = ret_df.max().values

# %%
ret_df = ret_df.rank(axis=1, pct=True)

# %%
df.loc[:, 'max percentage'] = ret_df.max().values

# %%
df.loc[:, 'max percentage date'] = ret_df.idxmax().values

# %%
df = df[df['max percentage'] > 0.9]

# %%
df = df.dropna()

# %%
df.loc[:, 'max percentage'] = 1 - df.loc[:, 'max percentage']

# %%
df = df.sort_values('max return', ascending=False)

# %%
df
# Out:
#           sec_name  wind_code investtype              issue_date  \
# 407         富国中证军工  161024.OF    被动指数型基金 2014-03-17 00:00:00.005
# 27       前海开源中证军工A  000596.OF    被动指数型基金 2014-04-08 00:00:00.005
# 681       汇丰晋信科技先锋  540010.OF    普通股票型基金 2011-06-20 00:00:00.005
# 18          富国城镇发展  000471.OF    普通股票型基金 2013-12-30 00:00:00.005
# 19         建信中证500  000478.OF    增强指数型基金 2014-01-02 00:00:00.005
# 467     申万菱信中证申万证券  163113.OF    被动指数型基金 2014-02-24 00:00:00.005
# 455      泰达宏利中证500  162216.OF    被动指数型基金 2011-10-24 00:00:00.005
# 495      信诚中证500分级  165511.OF    被动指数型基金 2011-01-06 00:00:00.005
# 380        鹏华中证500  160616.OF    被动指数型基金 2010-01-04 00:00:00.005
# 405        富国中证500  161017.OF    增强指数型基金 2011-09-09 00:00:00.005
# 684        中邮上证380  590007.OF    增强指数型基金 2011-09-28 00:00:00.005
# 358  南方中证500ETF联接A  160119.OF    被动指数型基金 2009-08-20 00:00:00.005
# 26          大摩进取优选  000594.OF    普通股票型基金 2014-05-06 00:00:00.005
# 463       泰信基本面400  162907.OF    被动指数型基金 2012-08-06 00:00:00.005
# 461  广发中证500ETF联接A  162711.OF    被动指数型基金 2009-10-22 00:00:00.005
# 540      申万菱信沪深300  310318.OF    增强指数型基金 2004-10-18 00:00:00.005
# 364        国泰国证房地产  160218.OF    被动指数型基金 2013-01-14 00:00:00.005
# 686      农银汇理中证500  660011.OF    被动指数型基金 2011-10-28 00:00:00.005
# 406      富国创业板指数分级  161022.OF    被动指数型基金 2013-08-12 00:00:00.005
# 660     浦银安盛基本面400  519117.OF    被动指数型基金 2012-04-05 00:00:00.005
# 7         大摩品质生活精选  000309.OF    普通股票型基金 2013-09-23 00:00:00.005
# 465       申万菱信量化小盘  163110.OF    普通股票型基金 2011-05-16 00:00:00.005
# 21        上投摩根民生需求  000524.OF    普通股票型基金 2014-02-17 00:00:00.005
# 521   南方小康产业ETF联接A  202021.OF    被动指数型基金 2010-07-26 00:00:00.005
# 482      工银瑞信中证500  164809.OF    被动指数型基金 2011-12-26 00:00:00.005
# 382    鹏华中证800证券保险  160625.OF    被动指数型基金 2014-04-03 00:00:00.005
# 449         万家中证红利  161907.OF    被动指数型基金 2011-02-14 00:00:00.005
# 22         华安大国新经济  000549.OF    普通股票型基金 2014-03-13 00:00:00.005
# 383       鹏华中证信息技术  160626.OF    被动指数型基金 2014-04-03 00:00:00.005
